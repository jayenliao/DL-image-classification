# %% [markdown]
# # Deep Learning - Assignment 1
#
# This is the python notebook with experiments for assignment 1 of Deep Learning, a course at Institute of Data Science, National Cheng Kung University.
#
# - Author: Jay C. Liao
# - ID: RE6094028
# - Email: re6094028@gs.ncku.edu.tw

# %%
import importlib
import args
import main
import trainers
import models
importlib.reload(args)
importlib.reload(main)
importlib.reload(trainers)
importlib.reload(models)
# Out:
# <module 'models' from '/home/jayliao2/DL_2021/hw1/models.py'>

# %% [markdown]
# ## Naive Perceptron

# %%
# %run main.py --models 'NaivePerceptron' --savePATH './output/_NaivePerceptron'
# Out:
# ======= Feature type: Histogram =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 15) (450, 15) (450, 15)
# Shapes of y label matrices (Train | Val | Test):  (63325, 50) (450, 50) (450, 50)
#
# ---> Model: NaivePerceptron
# lr = 0.01|
#
#
# Training a new model ...  (Batch size = 256, No. of epochs = 300)
# Epoch   30
#   Training accuracy: 0.0466 (top-1) 0.1822 (top-5)
# Validation accuracy: 0.0400 (top-1) 0.1800 (top-5)
# Epoch   60
#   Training accuracy: 0.0425 (top-1) 0.1435 (top-5)
# Validation accuracy: 0.0489 (top-1) 0.1311 (top-5)
# Epoch   90
#   Training accuracy: 0.0251 (top-1) 0.1198 (top-5)
# Validation accuracy: 0.0244 (top-1) 0.1200 (top-5)
# Epoch  120
#   Training accuracy: 0.0338 (top-1) 0.1348 (top-5)
# Validation accuracy: 0.0467 (top-1) 0.1667 (top-5)
# Epoch  150
#   Training accuracy: 0.0236 (top-1) 0.1234 (top-5)
# Validation accuracy: 0.0289 (top-1) 0.1222 (top-5)
# Epoch  180
# ...

# %%
# %run main.py --models 'NaivePerceptron' --savePATH './output/_NaivePerceptron' --epochs 500
# Out:
# ======= Feature type: Histogram =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 15) (450, 15) (450, 15)
# Shapes of y label matrices (Train | Val | Test):  (63325, 50) (450, 50) (450, 50)
#
# ---> Model: NaivePerceptron
# lr = 0.01|
#
#
# Training a new model ...  (Batch size = 256, No. of epochs = 500)
# Epoch   30
#   Training accuracy: 0.0466 (top-1) 0.1822 (top-5)
# Validation accuracy: 0.0400 (top-1) 0.1800 (top-5)
# Epoch   60
#   Training accuracy: 0.0425 (top-1) 0.1435 (top-5)
# Validation accuracy: 0.0489 (top-1) 0.1311 (top-5)
# Epoch   90
#   Training accuracy: 0.0251 (top-1) 0.1198 (top-5)
# Validation accuracy: 0.0244 (top-1) 0.1200 (top-5)
# Epoch  120
#   Training accuracy: 0.0338 (top-1) 0.1348 (top-5)
# Validation accuracy: 0.0467 (top-1) 0.1667 (top-5)
# Epoch  150
#   Training accuracy: 0.0236 (top-1) 0.1234 (top-5)
# Validation accuracy: 0.0289 (top-1) 0.1222 (top-5)
# Epoch  180
# ...

# %% [markdown]
# ## One-layer Perceptron

# %%
# %run main.py --models 'OneLayerPerceptron' --epochs 500 --savePATH './output/_OneLayerPerceptron'
# Out:
#  31%|███       | 77/247 [00:00<00:00, 766.58it/s]
# ======= Feature type: Histogram =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 15) (450, 15) (450, 15)
# Shapes of y label matrices (Train | Val | Test):  (63325, 50) (450, 50) (450, 50)
#
# ---> Model: OneLayerPerceptron
# lr = 0.01|  Optimizer: Adam | Act. fun. of the output layer: SoftmaxWithCrossEntropyLoss |
#
# Training a new model ...  (Batch size = 256, No. of epochs = 500)
# ...
#  14%|█▍        | 34/247 [00:00<00:00, 333.20it/s]
# Epoch   30
# Training loss=3.7160
#   Training accuracy: 0.0745 (top-1) 0.2537 (top-5)
# Validation accuracy: 0.0711 (top-1) 0.2689 (top-5)
# ...
#  25%|██▍       | 61/247 [00:00<00:00, 599.95it/s]
# Epoch   60
# Training loss=3.6905
#   Training accuracy: 0.0786 (top-1) 0.2653 (top-5)
# Validation accuracy: 0.0644 (top-1) 0.2844 (top-5)
# ...
#  24%|██▍       | 60/247 [00:00<00:00, 592.02it/s]
# Epoch   90
# Training loss=3.6468
# ...

# %% [markdown]
# ## Two-layer Network

# %%
# %run main.py --models 'TwoLayerNet' --hidden_layer_act 'None' --epochs 500 --savePATH './output/_TwoLayerNet'
# Out:
#  26%|██▌       | 63/247 [00:00<00:00, 623.39it/s]
# ======= Feature type: Histogram =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 15) (450, 15) (450, 15)
# Shapes of y label matrices (Train | Val | Test):  (63325, 50) (450, 50) (450, 50)
#
# ---> Model: TwoLayerNet
# lr = 0.01|  Optimizer: Adam | Hidden size: 32 | Activation function of the output layer: SoftmaxWithCrossEntropyLoss |
#
# Training a new model ...  (Batch size = 256, No. of epochs = 500)
# ...
#  18%|█▊        | 45/247 [00:00<00:00, 442.34it/s]
# Epoch   30
# Training loss=3.7148
#   Training accuracy: 0.0813 (top-1) 0.2753 (top-5)
# Validation accuracy: 0.0689 (top-1) 0.2933 (top-5)
# ...
#  24%|██▍       | 59/247 [00:00<00:00, 588.14it/s]
# Epoch   60
# Training loss=3.6445
#   Training accuracy: 0.0824 (top-1) 0.2783 (top-5)
# Validation accuracy: 0.0689 (top-1) 0.2889 (top-5)
# ...
#  24%|██▍       | 59/247 [00:00<00:00, 589.68it/s]
# Epoch   90
# Training loss=3.6429
# ...

# %% [markdown]
# ## Baselines

# %% [markdown]
# ### Random Forest Classifier

# %%
# %run main.py --models 'rf' --savePATH './output/_Baselines/'
# Out:
# ======= Feature type: Histogram =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 15) (450, 15) (450, 15)
# Training a new rf model ...
# Finish training! Time cost:    55.00 s
# The model is saved as ./output/_Baselines/21-03-18-09-05-13_Histogram_rf.pkl
#
# Evaluate the trained model on the testing set ...
# Top-1 accuracy=0.1289, Top-5 accuracy=0.2889
#
# ======= Feature type: SIFT =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 128) (450, 128) (450, 128)
# Training a new rf model ...
# Finish training! Time cost:   177.37 s
# The model is saved as ./output/_Baselines/21-03-18-09-08-17_SIFT_rf.pkl
#
# Evaluate the trained model on the testing set ...
# Top-1 accuracy=0.1778, Top-5 accuracy=0.4044
#
# ======= Feature type: SURF =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 64) (450, 64) (450, 64)
# ...

# %% [markdown]
# ### XGBoost Classifier

# %%
# %run main.py --models 'xgb' --savePATH './output/_Baselines/' --n_jobs 32
# Out:
# ======= Feature type: Histogram =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 15) (450, 15) (450, 15)
# Training a new xgb model ...
# Finish training! Time cost:    84.26 s
# The model is saved as ./output/_Baselines/21-03-17-16-53-10_Histogram_xgb.pkl
#
# Evaluate the trained model on the testing set ...
# Top-1 accuracy=0.1000, Top-5 accuracy=0.2800
#
# ======= Feature type: SIFT =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 128) (450, 128) (450, 128)
# Training a new xgb model ...
# Finish training! Time cost:   279.92 s
# The model is saved as ./output/_Baselines/21-03-17-16-57-50_SIFT_xgb.pkl
#
# Evaluate the trained model on the testing set ...
# Top-1 accuracy=0.1844, Top-5 accuracy=0.4778
#
# ======= Feature type: SURF =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 64) (450, 64) (450, 64)
# ...

# %% [markdown]
# ## Experiment of optimizer comparison

# %%
# %run exp_optimizers.py --savePATH './output/exp_optimizers/'
# Out:
#  23%|██▎       | 57/247 [00:00<00:00, 566.23it/s]
# ------------------ SGD ------------------
#
# ======= Feature type: SURF =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 64) (450, 64) (450, 64)
# Shapes of y label matrices (Train | Val | Test):  (63325, 50) (450, 50) (450, 50)
#
# ---> Model: TwoLayerNet
# lr = 0.01|  Optimizer: SGD | Hidden size: 32 | Act. fun. of the hidden layer: ReLU | Act. fun. of the output layer: SoftmaxWithCrossEntropyLoss |
#
# Training a new model ...  (Batch size = 256, No. of epochs = 300)
# ...
#  21%|██        | 52/247 [00:00<00:00, 518.50it/s]
# Epoch   30
# Training loss=3.9118
#   Training accuracy: 0.0202 (top-1) 0.1128 (top-5)
# Validation accuracy: 0.0200 (top-1) 0.1089 (top-5)
# ...
#  20%|█▉        | 49/247 [00:00<00:00, 488.57it/s]
# Epoch   60
# Training loss=3.9080
#   Training accuracy: 0.0198 (top-1) 0.1033 (top-5)
# Validation accuracy: 0.0200 (top-1) 0.1067 (top-5)
# ...

# %% [markdown]
# ## Experiment of number of bars in the global color histogram

# %%
# %run exp_n_Ranges.py --savePATH './output/exp_n_Ranges/' --n_Ranges_list 10 20 30 40 50 --epochs 100
# Out:
# ----> n_Ranges = 10
#
# ======= Feature type: Histogram =======
# Loading preprocessed datasets ...
# Loading the original images ...
#   0%|          | 6/63325 [00:00<20:38, 51.13it/s]
# Time cost of loading:   172.18s
#
# Extracting features ...
# ...
#  14%|█▍        | 34/247 [00:00<00:00, 333.60it/s]
# Time cost of feature extraction:  1960.74s
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 33) (450, 33) (450, 33)
# Shapes of y label matrices (Train | Val | Test):  (63325, 50) (450, 50) (450, 50)
#
# ---> Model: TwoLayerNet
# lr = 0.01|  Optimizer: Adam | Hidden size: 32 | Act. fun. of the hidden layer: ReLU | Act. fun. of the output layer: SoftmaxWithCrossEntropyLoss |
#
# Training a new model ...  (Batch size = 256, No. of epochs = 100)
# ...
#  18%|█▊        | 44/247 [00:00<00:00, 439.26it/s]
# Epoch   30
# Training loss=3.6462
#   Training accuracy: 0.0923 (top-1) 0.3051 (top-5)
# Validation accuracy: 0.0956 (top-1) 0.3178 (top-5)
# ...

# %%
# %run exp_n_Ranges.py --savePATH './output/exp_n_Ranges/' --n_Ranges_list 30 40 50 --epochs 100
# Out:
# ----> n_Ranges = 30
#
# ======= Feature type: Histogram =======
# Loading preprocessed datasets ...
# Loading the original images ...
#   0%|          | 2/63325 [00:00<59:59, 17.59it/s]
# Time cost of loading:   165.43s
#
# Extracting features ...
# ...
#  17%|█▋        | 43/247 [00:00<00:00, 418.82it/s]
# Time cost of feature extraction:  4487.73s
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 96) (450, 96) (450, 96)
# Shapes of y label matrices (Train | Val | Test):  (63325, 50) (450, 50) (450, 50)
#
# ---> Model: TwoLayerNet
# lr = 0.01|  Optimizer: Adam | Hidden size: 32 | Act. fun. of the hidden layer: ReLU | Act. fun. of the output layer: SoftmaxWithCrossEntropyLoss |
#
# Training a new model ...  (Batch size = 256, No. of epochs = 100)
# ...
#  17%|█▋        | 41/247 [00:00<00:00, 404.89it/s]
# Epoch   30
# Training loss=3.6444
#   Training accuracy: 0.0946 (top-1) 0.3113 (top-5)
# Validation accuracy: 0.1022 (top-1) 0.3178 (top-5)
# ...

# %%
# %run exp_n_Ranges.py --savePATH './output/exp_n_Ranges/' --n_Ranges_list 10 20 30 40 50 --epochs 100
# Out:
#   0%|          | 0/247 [00:00<?, ?it/s]
# ----> n_Ranges = 10
#
# ======= Feature type: Histogram =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 15) (450, 15) (450, 15)
# Shapes of y label matrices (Train | Val | Test):  (63325, 50) (450, 50) (450, 50)
#
# ---> Model: TwoLayerNet
# lr = 0.01|  Optimizer: Adam | Hidden size: 32 | Activation function of the output layer: SoftmaxWithCrossEntropyLoss |
#
# Training a new model ...  (Batch size = 256, No. of epochs = 100)
# ...
#  20%|██        | 50/247 [00:00<00:00, 498.75it/s]
# Epoch   30
# Training loss=3.6505
#   Training accuracy: 0.0900 (top-1) 0.2970 (top-5)
# Validation accuracy: 0.0889 (top-1) 0.3000 (top-5)
# ...
#  11%|█         | 27/247 [00:00<00:00, 267.34it/s]
# Epoch   60
# Training loss=3.5462
#   Training accuracy: 0.0969 (top-1) 0.3188 (top-5)
# Validation accuracy: 0.0889 (top-1) 0.3089 (top-5)
# ...
#  20%|█▉        | 49/247 [00:00<00:00, 488.34it/s]
# Epoch   90
# ...

# %%
# %run exp_n_Ranges.py --savePATH './output/exp_n_Ranges/' --n_Ranges_list 10 20 30 40 50 --epochs 100
# Out:
#   0%|          | 0/247 [00:00<?, ?it/s]
# ----> n_Ranges = 10
#
# ======= Feature type: Histogram =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 15) (450, 15) (450, 15)
# Shapes of y label matrices (Train | Val | Test):  (63325, 50) (450, 50) (450, 50)
#
# ---> Model: TwoLayerNet
# lr = 0.01|  Optimizer: Adam | Hidden size: 32 | Activation function of the output layer: SoftmaxWithCrossEntropyLoss |
#
# Training a new model ...  (Batch size = 256, No. of epochs = 100)
# ...
#  20%|██        | 50/247 [00:00<00:00, 491.47it/s]
# Epoch   30
# Training loss=3.6562
#   Training accuracy: 0.0886 (top-1) 0.2940 (top-5)
# Validation accuracy: 0.0889 (top-1) 0.3022 (top-5)
# ...
#  19%|█▉        | 47/247 [00:00<00:00, 466.30it/s]
# Epoch   60
# Training loss=3.5420
#   Training accuracy: 0.0944 (top-1) 0.3127 (top-5)
# Validation accuracy: 0.1000 (top-1) 0.3044 (top-5)
# ...
#  20%|█▉        | 49/247 [00:00<00:00, 479.78it/s]
# Epoch   90
# ...
